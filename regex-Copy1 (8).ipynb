# %% [markdown]
# ## PROJECT

# %%
import re
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
url5="https://www.flipkart.com/search?q=water+purifier&sid=j9e%2Cabm%2Ci45&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=water+purifier%7CWater+purifiers&requestId=9c79f456-bc40-43bb-8863-1f83b26825f5&as-searchtext=water+purifier%2Fpage%3D2&p%5B%5D=facets.brand%255B%255D%3DHAVELLS&p%5B%5D=facets.brand%255B%255D%3DKENT&p%5B%5D=facets.brand%255B%255D%3DAquafresh&p%5B%5D=facets.brand%255B%255D%3DPureit&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DLIVPURE&p%5B%5D=facets.brand%255B%255D%3DBlueLife&p%5B%5D=facets.brand%255B%255D%3DAquaguard"
page=requests.get(url5)
soup=BeautifulSoup(page.text)

# %%
import numpy as np
import pandas as pd
Brand = []
Model = []
Storage_Capacity = []
Technology = []
Rating=[]
Price=[]
suitability=[]
Discount=[]
No_Of_Reviews=[]
for i in range(1,19):
    url5="https://www.flipkart.com/search?q=water+purifier&sid=j9e%2Cabm%2Ci45&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=water+purifier%7CWater+purifiers&requestId=9c79f456-bc40-43bb-8863-1f83b26825f5&as-searchtext=water+purifier%2Fpage%3D2&p%5B%5D=facets.brand%255B%255D%3DHAVELLS&p%5B%5D=facets.brand%255B%255D%3DKENT&p%5B%5D=facets.brand%255B%255D%3DAquafresh&p%5B%5D=facets.brand%255B%255D%3DPureit&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DLIVPURE&p%5B%5D=facets.brand%255B%255D%3DBlueLife&p%5B%5D=facets.brand%255B%255D%3DAquaguard&page={i}"
    soup = BeautifulSoup(page.text)


    for i in soup.find_all("div",class_="KzDlHZ"):
        if re.findall(r"^\w+",i.text):
            Brand.append("".join(re.findall(r"^\w+",i.text)))
        else:
            Brand.append(np.nan)
        if re.findall(r"^\w+\s(.*)\s\d+\sL",i.text):
            Model.append("".join(re.findall(r"^\w+\s(.*)\s\d+\sL",i.text)))
        else:
            Model.append(np.nan)
        if re.findall(r"\d+\sL\s(.*)Water\sP",i.text):
            Technology.append("".join(re.findall(r"\d+\sL\s(.*)Water\sP",i.text)))
        else:
            Technology.append(np.nan)
        if re.findall(r"\d+\sL",i.text):
            Storage_Capacity.append("".join(re.findall(r"\d+\sL",i.text)))
        else:
            Storage_Capacity.append(np.nan)
    for i in soup.find_all("div",class_="UkUFwK"):
        if re.findall(r".*",i.text):
            Discount.append("".join(re.findall(r".*",i.text)))
        else:
            Discount.append(np.nan)
    for i in soup.find_all("div",class_="_5OesEi"):
        if re.findall(r"&\s(.*)\sR",i.text):
            No_Of_Reviews.append("".join(re.findall(r"&\s(.*)\sR",i.text)))
        else:
            No_Of_Reviews.append(np.nan)

    for i in soup.find_all("div",class_="XQDdHH"):
        if re.findall(r".*",i.text):
            Rating.append("".join(re.findall(r".*",i.text)))
        else:
            Rating.append(np.nan)
    for i in soup.find_all("div",class_="Nx9bqj _4b5DiR"):
        if re.findall(r".*",i.text):
            Price.append("".join(re.findall(r".*",i.text)))
        else:
            Price.append(np.nan)

# %%
waterrpurifiers=pd.DataFrame({"Brand":Brand,
"Model":Model,
"Storage Capacity":Storage_Capacity,
"Technology":Technology,
"Rating":Rating,
"Price":Price,
"No_of_Reviews":No_Of_Reviews,
"Discount":Discount})

# %%
waterrpurifiers
# Out:
#          Brand                               Model Storage Capacity  \
# 0      LIVPURE                   LIV-PEP-PRO-STAR.              7 L
# 1      LIVPURE                   LIV-PEP-PRO-PLUS+              7 L
# 2      LIVPURE                 LIV-PEP-STAR-COPPER              7 L
# 3    Aquaguard                         Delight NXT              6 L
# 4    Aquaguard                         Delight NXT              6 L
# ..         ...                                 ...              ...
# 427  Aquaguard                               Glory              6 L
# 428       KENT  Ace Copper - B//111134B ACE Copper              8 L
# 429    LIVPURE                     LIV-AVID-COPPER              8 L
# 430  Aquaguard                               Glory              6 L
# 431    HAVELLS                        FAB Alkaline              7 L
#
#                                             Technology Rating    Price  \
# 0                             RO + UV + UF + Minerals     4.2   ₹7,499
# ...

# %%
waterrpurifiers.isna().sum()
# Out:
# Brand               0
# Model               0
# Storage Capacity    0
# Technology          0
# Rating              0
# Price               0
# No_of_Reviews       0
# Discount            0
# dtype: int64

# %%
water_purifierss.to_csv(rf"C:\Users\91852\OneDrive\Documents\water_purifierss.csv")

# %%
print(len(Brand))
print(len(Model))
print(len(Storage_Capacity))
print(len(Technology))
print(len(Rating))
print(len(Price))
print(len(No_Of_Reviews))
print(len(Discount))
# Out:
# 432
# 432
# 432
# 432
# 432
# 432
# 432
# 432

# %%
water_purifiers.to_csv(rf"C:\Users\91852\OneDrive\Documents\web_scraping file\waterpurifier.csv")

# %%
url5="https://www.flipkart.com/search?q=water+purifier&sid=j9e%2Cabm%2Ci45&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&as-pos=1&as-type=RECENT&suggestionId=water+purifier%7CWater+purifiers&requestId=9c79f456-bc40-43bb-8863-1f83b26825f5&as-searchtext=water+purifier%2Fpage%3D2&p%5B%5D=facets.brand%255B%255D%3DHAVELLS&p%5B%5D=facets.brand%255B%255D%3DKENT&p%5B%5D=facets.brand%255B%255D%3DAquafresh&p%5B%5D=facets.brand%255B%255D%3DPureit&p%5B%5D=facets.brand%255B%255D%3DLG&p%5B%5D=facets.brand%255B%255D%3DLIVPURE&p%5B%5D=facets.brand%255B%255D%3DBlueLife&p%5B%5D=facets.brand%255B%255D%3DAquaguard&page=1"
page = requests.get(url5)
soup = BeautifulSoup(page.text)
soup.find_all("a","CGtC98")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
water_purifiers=pd.read_csv(rf"C:\Users\91852\OneDrive\Documents\web_scraping file\waterpurifier.csv")

# %%
water_purifiers
# Out:
#      Unnamed: 0      Brand                               Model  \
# 0             0    LIVPURE                   LIV-PEP-PRO-STAR.
# 1             1    LIVPURE                   LIV-PEP-PRO-PLUS+
# 2             2    LIVPURE                 LIV-PEP-STAR-COPPER
# 3             3  Aquaguard                         Delight NXT
# 4             4  Aquaguard                         Delight NXT
# ..          ...        ...                                 ...
# 427         427  Aquaguard                               Glory
# 428         428       KENT  Ace Copper - B//111134B ACE Copper
# 429         429    LIVPURE                     LIV-AVID-COPPER
# 430         430  Aquaguard                               Glory
# 431         431    HAVELLS                        FAB Alkaline
#
#     Storage Capacity                                         Technology  \
# 0                7 L                           RO + UV + UF + Minerals
# ...

# %%
water_purifiers.dtypes
# Out:
# Unnamed: 0            int64
# Brand                object
# Model                object
# Storage Capacity     object
# Technology           object
# Rating              float64
# Price                object
# No_of_Reviews        object
# Discount             object
# dtype: object

# %% [markdown]
# ## Data Cleaning

# %%
duplicates = water_purifiers.duplicated()
if duplicates.any():
    print("Duplicates found:")
    print(water_purifiers[duplicates])
else:
    print("No duplicates found")
# Out:
# No duplicates found

# %%
del water_purifiers['Unnamed: 0']

# %%
water_purifiers.isna().sum()
# Out:
# Brand               0
# Model               0
# Storage Capacity    0
# Technology          0
# Rating              0
# Price               0
# No_of_Reviews       0
# Discount            0
# dtype: int64

# %%
water_purifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             432 non-null    object
#  1   Model             432 non-null    object
#  2   Storage Capacity  432 non-null    object
#  3   Technology        432 non-null    object
#  4   Rating            432 non-null    float64
#  5   Price             432 non-null    object
#  6   No_of_Reviews     432 non-null    object
#  7   Discount          432 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 27.1+ KB

# %% [markdown]
# ## checking unique values in each column

# %%
for column in water_purifiers.columns:
    unique_values = water_purifiers[column].nunique()
    print(f"Unique values in {column}: {unique_values}")
# Out:
# Unique values in Brand: 5
# Unique values in Model: 21
# Unique values in Storage Capacity: 6
# Unique values in Technology: 18
# Unique values in Rating: 6
# Unique values in Price: 19
# Unique values in No_of_Reviews: 13
# Unique values in Discount: 18

# %% [markdown]
# ## Converting Datatypes

# %%
water_purifiers['Storage Capacity'] =water_purifiers['Storage Capacity'].str.replace('L','')

# %%
water_purifiers['Price'] = water_purifiers['Price'].str.replace('₹', '')

# %%
water_purifiers['Discount'] = water_purifiers['Discount'].str.replace('% off', '')

# %%
water_purifiers['Price'] = water_purifiers['Price'].str.replace(',', '')

# %%
water_purifiers['No_of_Reviews'] = water_purifiers['No_of_Reviews'].str.replace(',', '')

# %%
water_purifiers['Brand']=water_purifiers['Brand'].str.capitalize()

# %%
water_purifiers['Model'] =water_purifiers['Model'].astype('category')

# %%
water_purifiers['Technology'] =water_purifiers['Technology'].astype('category')

# %%
water_purifiers['Storage Capacity'] =water_purifiers['Storage Capacity'].astype('int32')

# %%
water_purifiers['Storage Capacity']=water_purifiers['Storage Capacity'].astype('category')

# %%
water_purifiers['Rating']=water_purifiers['Rating'].astype('category')

# %%
water_purifiers['Brand']=water_purifiers['Brand'].astype('category')

# %%
water_purifiers['Price']=water_purifiers['Price'].astype('int64')

# %%
water_purifiers['No_of_Reviews']=water_purifiers['No_of_Reviews'].astype('int64')

# %%
water_purifiers['Discount'] = water_purifiers['Discount'].astype('int32')

# %%
water_purifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             432 non-null    category
#  1   Model             432 non-null    category
#  2   Storage Capacity  432 non-null    category
#  3   Technology        432 non-null    category
#  4   Rating            432 non-null    category
#  5   Price             432 non-null    int64
#  6   No_of_Reviews     432 non-null    int64
#  7   Discount          432 non-null    int32
# dtypes: category(5), int32(1), int64(2)
# memory usage: 12.6 KB

# %%
water_purifiers.head()
# Out:
#        Brand                Model Storage Capacity  \
# 0    Livpure    LIV-PEP-PRO-STAR.                7
# 1    Livpure    LIV-PEP-PRO-PLUS+                7
# 2    Livpure  LIV-PEP-STAR-COPPER                7
# 3  Aquaguard          Delight NXT                6
# 4  Aquaguard          Delight NXT                6
#
#                           Technology Rating  Price  No_of_Reviews  Discount
# 0           RO + UV + UF + Minerals     4.2   7499           2120        54
# 1                      RO + UV + UF     4.3   6999          12189        54
# 2  RO + UV + UF + Minerals + Copper     4.3   8999          12189        51
# 3                           RO + MC     4.3   6899           2743        46
# 4                           RO + UV     4.3   7999           2743        42

# %% [markdown]
# ## Univariate Analysis

# %%
water_purifiers[['Price','Rating','No_of_Reviews','Rating']].describe()
# Out:
#               Price  No_of_Reviews
# count    432.000000     432.000000
# mean    9003.000000    4322.875000
# std     3555.148222    4385.555733
# min     1749.000000       1.000000
# 25%     7149.000000     265.000000
# 50%     8849.000000    2582.000000
# 75%    10624.000000    7388.000000
# max    16999.000000   12189.000000

# %%
water_purifiers[['Brand','Model','Technology','Storage Capacity']].describe(include='all')
# Out:
#           Brand        Model           Technology  Storage Capacity
# count       432          432                  432               432
# unique        5           21                   18                 6
# top     Livpure  Delight NXT  RO + UV + UF + TDS                  7
# freq        144           54                   54               162

# %% [markdown]
# ## VISUALISATIONS in Univariate

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
water_purifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             432 non-null    category
#  1   Model             432 non-null    category
#  2   Storage Capacity  432 non-null    category
#  3   Technology        432 non-null    category
#  4   Rating            432 non-null    category
#  5   Price             432 non-null    int64
#  6   No_of_Reviews     432 non-null    int64
#  7   Discount          432 non-null    int32
# dtypes: category(5), int32(1), int64(2)
# memory usage: 12.6 KB

# %%
water_purifiers.columns
# Out:
# Index(['Brand', 'Model', 'Storage Capacity', 'Technology', 'Rating', 'Price',
#        'No_of_Reviews', 'Discount'],
#       dtype='object')

# %%
plt.figure(figsize=(12,10))
plt.subplot(2,2,1)
plt.pie(water_purifiers['Brand'].value_counts(),autopct='%0.2f%%',labels=water_purifiers['Brand'].value_counts().index)
plt.title('PIE PLOT OF BRAND')
plt.figure(figsize=(10,7))
plt.subplot(2,2,3)
sns.countplot(data=water_purifiers,x='Storage Capacity',color='orange')
plt.title('COUNT PLOT OF STORAGE CAPACITY')
plt.subplot(2,2,4)
sns.countplot(data=water_purifiers,y='Technology',color='red')
plt.title('COUNT PLOT OF TECHNOLOGY')
plt.tight_layout()

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
sns.histplot(data=water_purifiers,x='Price',color='purple',kde=True)
plt.title('DISTRIBUTION OF PRICE')
plt.subplot(2,2,2)
sns.kdeplot(data=water_purifiers,x='Discount',color='cyan')
plt.title('KDE PLOT OF DISCOUNT')
plt.tight_layout()

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %% [markdown]
# #### NUMERICAL vs NUMERICAL

# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
water_purifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             432 non-null    category
#  1   Model             432 non-null    category
#  2   Storage Capacity  432 non-null    category
#  3   Technology        432 non-null    category
#  4   Rating            432 non-null    category
#  5   Price             432 non-null    int64
#  6   No_of_Reviews     432 non-null    int64
#  7   Discount          432 non-null    int32
# dtypes: category(5), int32(1), int64(2)
# memory usage: 12.6 KB

# %%
water_purifiers.head()
# Out:
#        Brand                Model Storage Capacity  \
# 0    Livpure    LIV-PEP-PRO-STAR.                7
# 1    Livpure    LIV-PEP-PRO-PLUS+                7
# 2    Livpure  LIV-PEP-STAR-COPPER                7
# 3  Aquaguard          Delight NXT                6
# 4  Aquaguard          Delight NXT                6
#
#                           Technology Rating  Price  No_of_Reviews  Discount
# 0           RO + UV + UF + Minerals     4.2   7499           2120        54
# 1                      RO + UV + UF     4.3   6999          12189        54
# 2  RO + UV + UF + Minerals + Copper     4.3   8999          12189        51
# 3                           RO + MC     4.3   6899           2743        46
# 4                           RO + UV     4.3   7999           2743        42

# %% [markdown]
# #### NUMERICAL VS CATEGORICAL

# %% [markdown]
# #### GROUPBY

# %%
water_purifiers.groupby(['Brand','Model'],observed=True)['Price'].apply(lambda x: x.value_counts())
# Out:
# Brand      Model
# Aquafresh  SUPER COPPER OD                     3704     18
#            TPT diemond 12Ltrs + copper filter  3899     18
# Aquaguard  Delight NXT                         6899     18
#                                                7999     18
#                                                8999     18
#            Glory                               10999    18
#                                                16999    18
# HAVELLS    Aquas                               7299     18
#            FAB Alkaline                        8999     18
# KENT       ACE - B                             10999    18
#            Ace                                 10499    18
#            Ace Copper - B//111134B ACE Copper  13999    18
#            Ace Extra/ Ace Alkaline             13499    18
#            Ace Lite                            9999     18
#            Gold Optima (11016)                 1749     18
#            Marvel (111166B)                    9999     18
# ...

# %%
water_purifiers['Storage Capacity']=water_purifiers['Storage Capacity'].astype('int32')

# %%
water_purifiers.groupby(['Brand','Technology'],observed=True)[['Price','Storage Capacity']].mean()
# Out:
#                                                                 Price  \
# Brand     Technology
# Aquafresh RO + UV + UF + Copper + TDS Control                  3899.0
#           RO + UV + UF + TDS                                   3704.0
# Aquaguard RO + MC                                              6899.0
#           RO + UV                                              7999.0
#           RO + UV + MTDS                                      16999.0
#           RO + UV + UF                                         8999.0
#           RO + UV + UF + MTDS                                 10999.0
# Havells   RO + UF                                              7299.0
#           RO + UV + Alkaline                                   8999.0
# Kent      Gravity Based + UF                                   1749.0
#           RO + UF + TDS                                        9999.0
#           RO + UV + UF + TDS                                  10749.0
# ...

# %% [markdown]
# #### VISUALISATIONS

# %%
water_purifiers.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 water_purifiers.info()
#
# NameError: name 'water_purifiers' is not defined

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
sns.boxplot(data=water_purifiers,x='Storage Capacity',y='Price',hue='Brand')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### CATEGORICAL VS CATEGORICAL

# %%
water_purifiers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 432 entries, 0 to 431
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             432 non-null    category
#  1   Model             432 non-null    category
#  2   Storage Capacity  432 non-null    category
#  3   Technology        432 non-null    category
#  4   Rating            432 non-null    category
#  5   Price             432 non-null    int64
#  6   No_of_Reviews     432 non-null    int64
#  7   Discount          432 non-null    int32
# dtypes: category(5), int32(1), int64(2)
# memory usage: 12.6 KB

# %%
plt.figure(figsize=(10,7))
plt.subplot(2,2,1)
sns.countplot(data=water_purifiers,y='Brand',hue='Storage Capacity')

plt.figure(figsize=(10,7))
plt.subplot(2,2,2)
sns.countplot(data=water_purifiers,y='Brand',hue='Rating')
# Out:
# <Axes: xlabel='count', ylabel='Brand'>

# %%
plt.figure(figsize=(12,20))
sns.countplot(data=water_purifiers,y='Technology',hue='Brand')
plt.ylabel("Technology", fontsize=22, fontweight='bold')  
plt.xlabel("Count", fontsize=22, fontweight='bold')  
plt.legend(title="Brand", fontsize=22, title_fontsize=14)
plt.xticks(fontsize=22, fontweight='bold')
plt.yticks(fontsize=22, fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(12,20))
sns.countplot(data=water_purifiers,y='Technology',hue='Storage Capacity')
plt.ylabel("Technology", fontsize=22, fontweight='bold')  
plt.xlabel("Count", fontsize=22, fontweight='bold')  
plt.legend(title="Storage Capacity", fontsize=22, title_fontsize=14)
plt.xticks(fontsize=22, fontweight='bold')
plt.yticks(fontsize=22, fontweight='bold')
plt.show()

# %%
water_purifiers.groupby('Technology',observed=True)['Price'].mean()
# Out:
# Technology
# Gravity Based + UF                                      1749.000000
# RO + MC                                                 6899.000000
# RO + UF                                                 7299.000000
# RO + UF + TDS                                           9999.000000
# RO + UV                                                 7999.000000
# RO + UV + Alkaline                                      8999.000000
# RO + UV + MTDS                                         16999.000000
# RO + UV + UF                                            7732.333333
# RO + UV + UF + Copper                                  15990.000000
# RO + UV + UF + Copper + TDS Control                     3899.000000
# RO + UV + UF + MTDS                                    10999.000000
# RO + UV + UF + Minerals                                 7499.000000
# RO + UV + UF + Minerals + Copper                        8849.000000
# RO + UV + UF + TDS                                      8400.666667
# ...
